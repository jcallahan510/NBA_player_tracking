# %%
import pandas
import os
import sys
import json

#import movement.config as CONFIG

data_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped'
csv_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/csv_folder/'
files = os.listdir(data_path)

if not os.path.exists(csv_path):
    os.makedirs(csv_path)

count = 0
movement_headers = ["team_id", "player_id", "x_loc", "y_loc", "radius", "game_clock", "shot_clock", "quarter", "game_id",
                    "event_id"]
for file in files:
    if '.json' not in file:
        continue
    try:
        count = count + 1
        
        if count > 100:
            break
        
        file_data = open('%s/%s' % (data_path, file))
        game_id = file.replace('.json', '')
        data = json.load(file_data)
        events = data['events']
        moments = []

        for event in events:
            event_id = event['eventId']
            movement_data = event['moments']
            for moment in movement_data:
                for player in moment[5]:
                    player.extend((moment[2], moment[3], moment[0], game_id, event_id))
                    moments.append(player)

        # movement frame is complete for game
        movement = pandas.DataFrame(moments, columns=movement_headers)
        movement.to_csv('%s/%s.csv' % (csv_path, game_id), index=False)
        # movement.to_json('./data/json/' + game_id + '.json', orient='records')
        
        

        print('\n')
        print('\n')
        print('Finished collecting dataframe for Game ID: ' + game_id)
        print('Completed : ' + str(count) + ' games.')
    except Exception as e:
        print('Error in loading: ' + str(file) + ' file, Error: ' + str(e))

print('\n')
print('\n')
print('Finished collecting dataframes for all games.')
print(str(count) + ' games counted')
# Out:
# Finished collecting dataframe for Game ID: 0021500631
# Completed : 1 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500618
# Completed : 2 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500634
# Completed : 3 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500568
# Completed : 4 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500532
# Completed : 5 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500540
# Completed : 6 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500546
# Completed : 7 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500528
# Completed : 8 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500659
# Completed : 9 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500549
# Completed : 10 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500628
# Completed : 11 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500467
# Completed : 12 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500507
# Completed : 13 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500630
# Completed : 14 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500516
# Completed : 15 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500545
# Completed : 16 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500459
# Completed : 17 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500548
# Completed : 18 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500523
# Completed : 19 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500552
# Completed : 20 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500525
# Completed : 21 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500458
# Completed : 22 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500511
# Completed : 23 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500624
# Completed : 24 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500586
# Completed : 25 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500621
# Completed : 26 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500574
# Completed : 27 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500453
# Completed : 28 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500575
# Completed : 29 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500492
# Completed : 30 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500529
# Completed : 31 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500530
# Completed : 32 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500509
# Completed : 33 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500463
# Completed : 34 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500464
# Completed : 35 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500660
# Completed : 36 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500513
# Completed : 37 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500479
# Completed : 38 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500490
# Completed : 39 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500497
# Completed : 40 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500580
# Completed : 41 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500536
# Completed : 42 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500465
# Completed : 43 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500565
# Completed : 44 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500651
# Completed : 45 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500520
# Completed : 46 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500539
# Completed : 47 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500626
# Completed : 48 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500662
# Completed : 49 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500491
# Completed : 50 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500578
# Completed : 51 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500637
# Completed : 52 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500620
# Completed : 53 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500487
# Completed : 54 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500623
# Completed : 55 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500657
# Completed : 56 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500521
# Completed : 57 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500600
# Completed : 58 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500510
# Completed : 59 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500653
# Completed : 60 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500527
# Completed : 61 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500461
# Completed : 62 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500484
# Completed : 63 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500627
# Completed : 64 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500488
# Completed : 65 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500473
# Completed : 66 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500572
# Completed : 67 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500561
# Completed : 68 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500485
# Completed : 69 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500560
# Completed : 70 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500541
# Completed : 71 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500573
# Completed : 72 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500569
# Completed : 73 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500544
# Completed : 74 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500543
# Completed : 75 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500462
# Completed : 76 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500477
# Completed : 77 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500633
# Completed : 78 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500593
# Completed : 79 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500508
# Completed : 80 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500512
# Completed : 81 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500550
# Completed : 82 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500457
# Completed : 83 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500505
# Completed : 84 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500493
# Completed : 85 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500501
# Completed : 86 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500533
# Completed : 87 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500514
# Completed : 88 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500557
# Completed : 89 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500646
# Completed : 90 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500595
# Completed : 91 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500663
# Completed : 92 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500570
# Completed : 93 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500619
# Completed : 94 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500496
# Completed : 95 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500556
# Completed : 96 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500460
# Completed : 97 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500553
# Completed : 98 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500577
# Completed : 99 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500517
# Completed : 100 games.
#
#
#
#
# Finished collecting dataframes for all games.
# 101 games counted

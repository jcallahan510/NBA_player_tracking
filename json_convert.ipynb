# %%
import pandas as pd
import os
import sys
import json
#!pip install movement
#import movement.config as CONFIG

# %%
with open('data/0021500520.json') as file:
    data = json.load(file)
    
file.close()

# %%
movement_headers = ["team_id", "player_id", "x_loc", "y_loc", "radius", "game_clock", "shot_clock", "quarter", "game_id",
                    "event_id"]

csv_path = '/Users/Joey/Projects/xefgi/data/'
game_id = '0021500520'

moments = []

events = data['events']
for event in events:
    event_id = event['eventId']
    movement_data = event['moments']
    for moment in movement_data:
        for player in moment[5]:
            player.extend((moment[2], moment[3], moment[0], game_id, event_id))
            moments.append(player)
# movement frame is complete for game
movement = pd.DataFrame(moments, columns=movement_headers)
movement.to_csv('%s/%s.csv' % (csv_path, game_id), index=False)

# %%
movement = pd.read_csv(csv_path+'0021500504.csv')
events = pd.read_csv(csv_path+'0021500504_e.csv')

# %%
events
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    21500504         0            12                   0       1
# 1    21500504         1            10                   0       1
# 2    21500504         2             1                  52       1
# 3    21500504         3             2                   1       1
# 4    21500504         4             4                   0       1
# 5    21500504         5             1                  79       1
# 6    21500504         6             1                   5       1
# 7    21500504         7             1                  79       1
# 8    21500504         8             2                  79       1
# 9    21500504         9             4                   0       1
# 10   21500504        10             2                   1       1
# 11   21500504        11             4                   0       1
# 12   21500504        12             7                   5       1
# 13   21500504        13             2                  58       1
# 14   21500504        14             4                   0       1
# 15   21500504        15             1                  79       1
# 16   21500504        16             9                   1       1
# 17   21500504        18             5                   2       1
# 18   21500504        19             1                  76       1
# 19   21500504        20             2                   1       1
# 20   21500504        21             4                   0       1
# 21   21500504        22             5                   4       1
# 22   21500504        23             1                  79       1
# 23   21500504        24             6                   1       1
# 24   21500504        25             8                   0       1
# 25   21500504        26             2                   1       1
# 26   21500504        27             4                   0       1
# 27   21500504        28             1                  79       1
# 28   21500504        29             2                   1       1
# 29   21500504        30             4                   0       1
# ..        ...       ...           ...                 ...     ...
# 473  21500504       535             2                  78       5
# 474  21500504       536             4                   0       5
# 475  21500504       537             1                   5       5
# 476  21500504       538             6                   4       5
# 477  21500504       539             5                   5       5
# 478  21500504       540             6                   1       5
# 479  21500504       541             2                   1       5
# 480  21500504       542             4                   0       5
# 481  21500504       543             6                   3       5
# 482  21500504       544             2                  79       5
# 483  21500504       545             4                   0       5
# 484  21500504       546             6                   4       5
# 485  21500504       547             5                   5       5
# 486  21500504       548             9                   1       5
# 487  21500504       550             1                   1       5
# 488  21500504       551             1                  82       5
# 489  21500504       552             1                  75       5
# 490  21500504       554             8                   0       5
# 491  21500504       555             8                   0       5
# 492  21500504       556             2                   1       5
# 493  21500504       557             4                   0       5
# 494  21500504       558             6                  28       5
# 495  21500504       559             3                  11       5
# 496  21500504       561             3                  12       5
# 497  21500504       563             4                   0       5
# 498  21500504       564             9                   1       5
# 499  21500504       566             8                   0       5
# 500  21500504       567             2                  79       5
# 501  21500504       568             4                   0       5
# 502  21500504       569            13                   0       5
#
#     WCTIMESTRING PCTIMESTRING  \
# 0       10:41 PM        12:00
# 1       10:41 PM        12:00
# 2       10:42 PM        11:47
# 3       10:42 PM        11:30
# 4       10:42 PM        11:29
# 5       10:42 PM        11:20
# 6       10:42 PM        11:00
# 7       10:43 PM        10:40
# 8       10:43 PM        10:27
# 9       10:43 PM        10:26
# 10      10:43 PM        10:17
# 11      10:43 PM        10:17
# 12      10:43 PM        10:17
# 13      10:44 PM         9:58
# 14      10:44 PM         9:56
# 15      10:44 PM         9:42
# 16      10:44 PM         9:41
# 17      10:46 PM         9:30
# 18      10:47 PM         9:25
# 19      10:47 PM         9:06
# 20      10:47 PM         9:05
# 21      10:47 PM         9:01
# 22      10:47 PM         8:48
# 23      10:48 PM         8:30
# 24      10:48 PM         8:30
# 25      10:48 PM         8:24
# 26      10:48 PM         8:24
# 27      10:48 PM         8:08
# 28      10:49 PM         7:45
# 29      10:49 PM         7:44
# ..           ...          ...
# 473     12:55 AM         2:21
# 474     12:55 AM         2:20
# 475     12:55 AM         2:18
# 476     12:56 AM         2:05
# 477     12:56 AM         2:05
# 478     12:56 AM         1:44
# 479     12:57 AM         1:34
# 480     12:57 AM         1:34
# 481     12:57 AM         1:34
# 482     12:57 AM         1:14
# 483     12:57 AM         1:12
# 484     12:58 AM         0:57
# 485     12:58 AM         0:57
# 486     12:58 AM         0:57
# 487      1:01 AM         0:47
# 488      1:01 AM         0:33
# 489      1:01 AM         0:15
# 490      1:04 AM         0:15
# 491      1:04 AM         0:15
# 492      1:04 AM         0:06
# 493      1:04 AM         0:06
# 494      1:04 AM         0:06
# 495      1:05 AM         0:06
# 496      1:05 AM         0:06
# 497      1:05 AM         0:06
# 498      1:05 AM         0:06
# 499      1:06 AM         0:06
# 500      1:07 AM         0:01
# 501      1:07 AM         0:00
# 502      1:07 AM         0:00
#
#                                        HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 0                                                  NaN                 NaN
# 1              Jump Ball Bogut vs. Jokic: Tip to Green                 NaN
# 2       Iguodala  Alley Oop Dunk (2 PTS) (Curry 1 AST)                 NaN
# 3                                                  NaN                 NaN
# 4                          Curry REBOUND (Off:0 Def:1)                 NaN
# 5    Green 27' 3PT Pullup Jump Shot (3 PTS) (Curry ...                 NaN
# 6                                                  NaN                 NaN
# 7    Green 26' 3PT Pullup Jump Shot (6 PTS) (Thomps...                 NaN
# 8                                                  NaN                 NaN
# 9                          Green REBOUND (Off:0 Def:1)                 NaN
# 10                     MISS Thompson 26' 3PT Jump Shot                 NaN
# 11                                                 NaN                 NaN
# 12              Bogut Violation:Kicked Ball (J.Capers)                 NaN
# 13                                                 NaN                 NaN
# 14                         Bogut REBOUND (Off:0 Def:1)                 NaN
# 15   Green 25' 3PT Pullup Jump Shot (9 PTS) (Iguoda...                 NaN
# 16                                                 NaN                 NaN
# 17                                 Green STEAL (1 STL)                 NaN
# 18   Curry 1' Running Finger Roll Layup (2 PTS) (Gr...                 NaN
# 19                                                 NaN                 NaN
# 20                                                 NaN                 NaN
# 21                                                 NaN                 NaN
# 22   Green 25' 3PT Pullup Jump Shot (12 PTS) (Iguod...                 NaN
# 23                     Curry P.FOUL (P1.T1) (J.Capers)                 NaN
# 24                                                 NaN                 NaN
# 25                                                 NaN                 NaN
# 26                      Thompson REBOUND (Off:0 Def:1)                 NaN
# 27   Iguodala  3PT Pullup Jump Shot (5 PTS) (Green ...                 NaN
# 28                                                 NaN                 NaN
# 29                         Bogut REBOUND (Off:0 Def:2)                 NaN
# ..                                                 ...                 ...
# 473                                                NaN                 NaN
# 474                                                NaN                 NaN
# 475                                                NaN                 NaN
# 476                     Clark OFF.Foul (P2) (J.Capers)                 NaN
# 477                       Clark Foul Turnover (P3.T14)                 NaN
# 478                    Green P.FOUL (P4.T3) (J.Capers)                 NaN
# 479                                                NaN                 NaN
# 480                                   WARRIORS Rebound                 NaN
# 481                                                NaN                 NaN
# 482                MISS Green 25' 3PT Pullup Jump Shot                 NaN
# 483                                                NaN                 NaN
# 484                                                NaN                 NaN
# 485                                                NaN                 NaN
# 486         WARRIORS Timeout: Regular (Full 6 Short 1)                 NaN
# 487      Speights 17' Jump Shot (8 PTS) (Green 13 AST)                 NaN
# 488                                                NaN                 NaN
# 489  Thompson 2' Driving Finger Roll Layup (25 PTS)...                 NaN
# 490                                                NaN                 NaN
# 491                          SUB: Livingston FOR Clark                 NaN
# 492                                                NaN                 NaN
# 493                     Speights REBOUND (Off:3 Def:5)                 NaN
# 494                                                NaN                 NaN
# 495                Thompson Free Throw 1 of 2 (26 PTS)                 NaN
# 496                    MISS Thompson Free Throw 2 of 2                 NaN
# 497                                                NaN                 NaN
# 498                                                NaN                 NaN
# 499                            SUB: Clark FOR Speights                 NaN
# 500                                                NaN                 NaN
# 501                                                NaN                 NaN
# 502                                                NaN                 NaN
#
#                                     VISITORDESCRIPTION  ... PLAYER2_TEAM_CITY  \
# 0                                                  NaN  ...               NaN
# 1                                                  NaN  ...            Denver
# 2                                                  NaN  ...      Golden State
# 3                         MISS Gallinari 20' Jump Shot  ...               NaN
# 4                                                  NaN  ...               NaN
# 5                                                  NaN  ...      Golden State
# 6             Gallinari 3' Layup (2 PTS) (Jokic 1 AST)  ...            Denver
# 7                                                  NaN  ...      Golden State
# 8                     MISS Harris 22' Pullup Jump Shot  ...               NaN
# 9                                                  NaN  ...               NaN
# 10                                                 NaN  ...               NaN
# 11                                     Nuggets Rebound  ...               NaN
# 12                                                 NaN  ...               NaN
# 13                 MISS Faried 8' Turnaround Hook Shot  ...               NaN
# 14                                                 NaN  ...               NaN
# 15                                                 NaN  ...      Golden State
# 16            Nuggets Timeout: Regular (Reg.1 Short 0)  ...               NaN
# 17                    Jokic Lost Ball Turnover (P1.T1)  ...      Golden State
# 18                                                 NaN  ...      Golden State
# 19                    MISS Gallinari 27' 3PT Jump Shot  ...               NaN
# 20                        Faried REBOUND (Off:1 Def:0)  ...               NaN
# 21                   Faried Traveling Turnover (P1.T2)  ...               NaN
# 22                                                 NaN  ...      Golden State
# 23                                                 NaN  ...            Denver
# 24                              SUB: Barton FOR Faried  ...            Denver
# 25                       MISS Nelson 25' 3PT Jump Shot  ...               NaN
# 26                                                 NaN  ...               NaN
# 27                                                 NaN  ...      Golden State
# 28                           MISS Barton 21' Jump Shot  ...               NaN
# 29                                                 NaN  ...               NaN
# ..                                                 ...  ...               ...
# 473                 MISS Barton 10' Floating Jump Shot  ...               NaN
# 474                       Faried REBOUND (Off:9 Def:3)  ...               NaN
# 475                           Faried 1' Layup (13 PTS)  ...               NaN
# 476                                                NaN  ...            Denver
# 477                                                NaN  ...               NaN
# 478                                                NaN  ...            Denver
# 479                          MISS Nelson 20' Jump Shot  ...               NaN
# 480                                                NaN  ...               NaN
# 481                 Faried L.B.FOUL (P3.T2) (J.Capers)  ...      Golden State
# 482                                                NaN  ...               NaN
# 483                    Gallinari REBOUND (Off:3 Def:3)  ...               NaN
# 484                    Barton OFF.Foul (P3) (M.Ayotte)  ...      Golden State
# 485                      Barton Foul Turnover (P5.T13)  ...               NaN
# 486                                                NaN  ...               NaN
# 487                                                NaN  ...      Golden State
# 488  Faried 8' Driving Bank Shot (15 PTS) (Nelson 7...  ...            Denver
# 489                                                NaN  ...      Golden State
# 490                             SUB: Arthur FOR Faried  ...            Denver
# 491                                                NaN  ...      Golden State
# 492                          MISS Barton 11' Jump Shot  ...               NaN
# 493                                                NaN  ...               NaN
# 494       Harris Personal Take Foul (P2.PN) (M.Ayotte)  ...      Golden State
# 495                                                NaN  ...               NaN
# 496                                                NaN  ...               NaN
# 497                       Arthur REBOUND (Off:3 Def:1)  ...               NaN
# 498           Nuggets Timeout: Regular (Reg.5 Short 2)  ...               NaN
# 499                                                NaN  ...      Golden State
# 500               MISS Barton 26' 3PT Pullup Jump Shot  ...               NaN
# 501                                    Nuggets Rebound  ...               NaN
# 502                                                NaN  ...               NaN
#
#     PLAYER2_TEAM_NICKNAME  PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE PLAYER3_ID  \
# 0                     NaN                        NaN            0          0
# 1                 Nuggets                        DEN            4     203110
# 2                Warriors                        GSW            0          0
# 3                     NaN                        NaN            0          0
# 4                     NaN                        NaN            0          0
# 5                Warriors                        GSW            0          0
# 6                 Nuggets                        DEN            0          0
# 7                Warriors                        GSW            0          0
# 8                     NaN                        NaN            0          0
# 9                     NaN                        NaN            0          0
# 10                    NaN                        NaN            0          0
# 11                    NaN                        NaN            0          0
# 12                    NaN                        NaN            1          0
# 13                    NaN                        NaN            0          0
# 14                    NaN                        NaN            0          0
# 15               Warriors                        GSW            0          0
# 16                    NaN                        NaN            0          0
# 17               Warriors                        GSW            0          0
# 18               Warriors                        GSW            0          0
# 19                    NaN                        NaN            0          0
# 20                    NaN                        NaN            0          0
# 21                    NaN                        NaN            1          0
# 22               Warriors                        GSW            0          0
# 23                Nuggets                        DEN            1          0
# 24                Nuggets                        DEN            0          0
# 25                    NaN                        NaN            0          0
# 26                    NaN                        NaN            0          0
# 27               Warriors                        GSW            0          0
# 28                    NaN                        NaN            0          0
# 29                    NaN                        NaN            0          0
# ..                    ...                        ...          ...        ...
# 473                   NaN                        NaN            0          0
# 474                   NaN                        NaN            0          0
# 475                   NaN                        NaN            0          0
# 476               Nuggets                        DEN            1          0
# 477                   NaN                        NaN            1          0
# 478               Nuggets                        DEN            1          0
# 479                   NaN                        NaN            0          0
# 480                   NaN                        NaN            0          0
# 481              Warriors                        GSW            1          0
# 482                   NaN                        NaN            0          0
# 483                   NaN                        NaN            0          0
# 484              Warriors                        GSW            1          0
# 485                   NaN                        NaN            1          0
# 486                   NaN                        NaN            0          0
# 487              Warriors                        GSW            0          0
# 488               Nuggets                        DEN            0          0
# 489              Warriors                        GSW            0          0
# 490               Nuggets                        DEN            0          0
# 491              Warriors                        GSW            0          0
# 492                   NaN                        NaN            0          0
# 493                   NaN                        NaN            0          0
# 494              Warriors                        GSW            1          0
# 495                   NaN                        NaN            0          0
# 496                   NaN                        NaN            0          0
# 497                   NaN                        NaN            0          0
# 498                   NaN                        NaN            0          0
# 499              Warriors                        GSW            0          0
# 500                   NaN                        NaN            0          0
# 501                   NaN                        NaN            0          0
# 502                   NaN                        NaN            0          0
#
#        PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 0               NaN             NaN               NaN                   NaN
# 1    Draymond Green    1.610613e+09      Golden State              Warriors
# 2               NaN             NaN               NaN                   NaN
# 3               NaN             NaN               NaN                   NaN
# 4               NaN             NaN               NaN                   NaN
# 5               NaN             NaN               NaN                   NaN
# 6               NaN             NaN               NaN                   NaN
# 7               NaN             NaN               NaN                   NaN
# 8               NaN             NaN               NaN                   NaN
# 9               NaN             NaN               NaN                   NaN
# 10              NaN             NaN               NaN                   NaN
# 11              NaN             NaN               NaN                   NaN
# 12              NaN             NaN               NaN                   NaN
# 13              NaN             NaN               NaN                   NaN
# 14              NaN             NaN               NaN                   NaN
# 15              NaN             NaN               NaN                   NaN
# 16              NaN             NaN               NaN                   NaN
# 17              NaN             NaN               NaN                   NaN
# 18              NaN             NaN               NaN                   NaN
# 19              NaN             NaN               NaN                   NaN
# 20              NaN             NaN               NaN                   NaN
# 21              NaN             NaN               NaN                   NaN
# 22              NaN             NaN               NaN                   NaN
# 23              NaN             NaN               NaN                   NaN
# 24              NaN             NaN               NaN                   NaN
# 25              NaN             NaN               NaN                   NaN
# 26              NaN             NaN               NaN                   NaN
# 27              NaN             NaN               NaN                   NaN
# 28              NaN             NaN               NaN                   NaN
# 29              NaN             NaN               NaN                   NaN
# ..              ...             ...               ...                   ...
# 473             NaN             NaN               NaN                   NaN
# 474             NaN             NaN               NaN                   NaN
# 475             NaN             NaN               NaN                   NaN
# 476             NaN             NaN               NaN                   NaN
# 477             NaN             NaN               NaN                   NaN
# 478             NaN             NaN               NaN                   NaN
# 479             NaN             NaN               NaN                   NaN
# 480             NaN             NaN               NaN                   NaN
# 481             NaN             NaN               NaN                   NaN
# 482             NaN             NaN               NaN                   NaN
# 483             NaN             NaN               NaN                   NaN
# 484             NaN             NaN               NaN                   NaN
# 485             NaN             NaN               NaN                   NaN
# 486             NaN             NaN               NaN                   NaN
# 487             NaN             NaN               NaN                   NaN
# 488             NaN             NaN               NaN                   NaN
# 489             NaN             NaN               NaN                   NaN
# 490             NaN             NaN               NaN                   NaN
# 491             NaN             NaN               NaN                   NaN
# 492             NaN             NaN               NaN                   NaN
# 493             NaN             NaN               NaN                   NaN
# 494             NaN             NaN               NaN                   NaN
# 495             NaN             NaN               NaN                   NaN
# 496             NaN             NaN               NaN                   NaN
# 497             NaN             NaN               NaN                   NaN
# 498             NaN             NaN               NaN                   NaN
# 499             NaN             NaN               NaN                   NaN
# 500             NaN             NaN               NaN                   NaN
# 501             NaN             NaN               NaN                   NaN
# 502             NaN             NaN               NaN                   NaN
#
#      PLAYER3_TEAM_ABBREVIATION
# 0                          NaN
# 1                          GSW
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ..                         ...
# 473                        NaN
# 474                        NaN
# 475                        NaN
# 476                        NaN
# 477                        NaN
# 478                        NaN
# 479                        NaN
# 480                        NaN
# 481                        NaN
# 482                        NaN
# 483                        NaN
# 484                        NaN
# 485                        NaN
# 486                        NaN
# 487                        NaN
# 488                        NaN
# 489                        NaN
# 490                        NaN
# 491                        NaN
# 492                        NaN
# 493                        NaN
# 494                        NaN
# 495                        NaN
# 496                        NaN
# 497                        NaN
# 498                        NaN
# 499                        NaN
# 500                        NaN
# 501                        NaN
# 502                        NaN
#
# [503 rows x 33 columns]

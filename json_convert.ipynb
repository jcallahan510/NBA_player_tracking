# %%
import pandas
import os
import sys
import json

#import movement.config as CONFIG

data_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/json_folder_5'
csv_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/csv_folder/'
files = os.listdir(data_path)

if not os.path.exists(csv_path):
    os.makedirs(csv_path)

count = 0
movement_headers = ["team_id", "player_id", "x_loc", "y_loc", "radius", "game_clock", "shot_clock", "quarter", "game_id",
                    "event_id"]
for file in files:
    if '.json' not in file:
        continue
    try:
        count = count + 1
        
        if count > 100:
            break
        
        file_data = open('%s/%s' % (data_path, file))
        game_id = file.replace('.json', '')
        data = json.load(file_data)
        events = data['events']
        moments = []

        for event in events:
            event_id = event['eventId']
            movement_data = event['moments']
            for moment in movement_data:
                for player in moment[5]:
                    player.extend((moment[2], moment[3], moment[0], game_id, event_id))
                    moments.append(player)

        # movement frame is complete for game
        movement = pandas.DataFrame(moments, columns=movement_headers)
        movement.to_csv('%s/%s.csv' % (csv_path, game_id), index=False)
        # movement.to_json('./data/json/' + game_id + '.json', orient='records')
        
        

        print('\n')
        print('\n')
        print('Finished collecting dataframe for Game ID: ' + game_id)
        print('Completed : ' + str(count) + ' games.')
    except Exception as e:
        print('Error in loading: ' + str(file) + ' file, Error: ' + str(e))

print('\n')
print('\n')
print('Finished collecting dataframes for all games.')
print(str(count) + ' games counted')
# Out:
# Finished collecting dataframe for Game ID: 0021500298
# Completed : 1 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500320
# Completed : 2 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500292
# Completed : 3 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500334
# Completed : 4 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500295
# Completed : 5 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500299
# Completed : 6 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500323
# Completed : 7 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500266
# Completed : 8 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500267
# Completed : 9 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500349
# Completed : 10 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500331
# Completed : 11 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500343
# Completed : 12 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500283
# Completed : 13 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500274
# Completed : 14 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500326
# Completed : 15 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500309
# Completed : 16 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500317
# Completed : 17 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500253
# Completed : 18 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500262
# Completed : 19 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500269
# Completed : 20 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500327
# Completed : 21 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500259
# Completed : 22 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500336
# Completed : 23 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500257
# Completed : 24 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500251
# Completed : 25 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500348
# Completed : 26 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500339
# Completed : 27 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500305
# Completed : 28 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500308
# Completed : 29 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500285
# Completed : 30 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500329
# Completed : 31 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500340
# Completed : 32 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500271
# Completed : 33 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500316
# Completed : 34 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500300
# Completed : 35 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500304
# Completed : 36 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500337
# Completed : 37 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500270
# Completed : 38 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500278
# Completed : 39 games.
# Error in loading: 0021500342.json file, Error: Expecting value: line 1 column 1 (char 0)
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500294
# Completed : 41 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500296
# Completed : 42 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500345
# Completed : 43 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500303
# Completed : 44 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500264
# Completed : 45 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500260
# Completed : 46 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500347
# Completed : 47 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500261
# Completed : 48 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500333
# Completed : 49 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500311
# Completed : 50 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500335
# Completed : 51 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500338
# Completed : 52 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500332
# Completed : 53 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500315
# Completed : 54 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500265
# Completed : 55 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500301
# Completed : 56 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500313
# Completed : 57 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500293
# Completed : 58 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500254
# Completed : 59 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500286
# Completed : 60 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500277
# Completed : 61 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500322
# Completed : 62 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500252
# Completed : 63 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500290
# Completed : 64 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500310
# Completed : 65 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500344
# Completed : 66 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500281
# Completed : 67 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500325
# Completed : 68 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500284
# Completed : 69 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500272
# Completed : 70 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500256
# Completed : 71 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500330
# Completed : 72 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500275
# Completed : 73 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500314
# Completed : 74 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500297
# Completed : 75 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500306
# Completed : 76 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500280
# Completed : 77 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500273
# Completed : 78 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500318
# Completed : 79 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500263
# Completed : 80 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500289
# Completed : 81 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500302
# Completed : 82 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500341
# Completed : 83 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500279
# Completed : 84 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500291
# Completed : 85 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500328
# Completed : 86 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500288
# Completed : 87 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500307
# Completed : 88 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500268
# Completed : 89 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500321
# Completed : 90 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500287
# Completed : 91 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500312
# Completed : 92 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500319
# Completed : 93 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500324
# Completed : 94 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500258
# Completed : 95 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500350
# Completed : 96 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500255
# Completed : 97 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500346
# Completed : 98 games.
#
#
#
#
# Finished collecting dataframes for all games.
# 98 games counted

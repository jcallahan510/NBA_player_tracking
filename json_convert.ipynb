# %%
import pandas
import os
import sys
import json

#import movement.config as CONFIG

data_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/json_folder_5'
csv_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/csv_folder/'
files = os.listdir(data_path)

if not os.path.exists(csv_path):
    os.makedirs(csv_path)

count = 0
movement_headers = ["team_id", "player_id", "x_loc", "y_loc", "radius", "game_clock", "shot_clock", "quarter", "game_id",
                    "event_id"]
for file in files:
    if '.json' not in file:
        continue
    try:
        count = count + 1
        
        if count > 100:
            break
        
        file_data = open('%s/%s' % (data_path, file))
        game_id = file.replace('.json', '')
        data = json.load(file_data)
        events = data['events']
        moments = []

        for event in events:
            event_id = event['eventId']
            movement_data = event['moments']
            for moment in movement_data:
                for player in moment[5]:
                    player.extend((moment[2], moment[3], moment[0], game_id, event_id))
                    moments.append(player)

        # movement frame is complete for game
        movement = pandas.DataFrame(moments, columns=movement_headers)
        movement.to_csv('%s/%s.csv' % (csv_path, game_id), index=False)
        # movement.to_json('./data/json/' + game_id + '.json', orient='records')
        
        

        print('\n')
        print('\n')
        print('Finished collecting dataframe for Game ID: ' + game_id)
        print('Completed : ' + str(count) + ' games.')
    except Exception as e:
        print('Error in loading: ' + str(file) + ' file, Error: ' + str(e))

print('\n')
print('\n')
print('Finished collecting dataframes for all games.')
print(str(count) + ' games counted')
# Out:
# Finished collecting dataframe for Game ID: 0021500374
# Completed : 1 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500351
# Completed : 2 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500437
# Completed : 3 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500424
# Completed : 4 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500426
# Completed : 5 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500449
# Completed : 6 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500392
# Completed : 7 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500361
# Completed : 8 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500362
# Completed : 9 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500419
# Completed : 10 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500368
# Completed : 11 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500438
# Completed : 12 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500447
# Completed : 13 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500384
# Completed : 14 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500403
# Completed : 15 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500436
# Completed : 16 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500423
# Completed : 17 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500371
# Completed : 18 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500385
# Completed : 19 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500376
# Completed : 20 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500397
# Completed : 21 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500353
# Completed : 22 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500370
# Completed : 23 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500407
# Completed : 24 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500409
# Completed : 25 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500410
# Completed : 26 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500367
# Completed : 27 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500366
# Completed : 28 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500446
# Completed : 29 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500390
# Completed : 30 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500369
# Completed : 31 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500406
# Completed : 32 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500421
# Completed : 33 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500445
# Completed : 34 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500360
# Completed : 35 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500418
# Completed : 36 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500383
# Completed : 37 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500441
# Completed : 38 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500412
# Completed : 39 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500388
# Completed : 40 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500387
# Completed : 41 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500405
# Completed : 42 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500416
# Completed : 43 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500448
# Completed : 44 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500357
# Completed : 45 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500444
# Completed : 46 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500422
# Completed : 47 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500427
# Completed : 48 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500442
# Completed : 49 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500430
# Completed : 50 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500399
# Completed : 51 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500378
# Completed : 52 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500431
# Completed : 53 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500386
# Completed : 54 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500402
# Completed : 55 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500433
# Completed : 56 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500439
# Completed : 57 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500365
# Completed : 58 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500429
# Completed : 59 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500356
# Completed : 60 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500389
# Completed : 61 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500425
# Completed : 62 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500375
# Completed : 63 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500440
# Completed : 64 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500372
# Completed : 65 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500414
# Completed : 66 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500404
# Completed : 67 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500358
# Completed : 68 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500417
# Completed : 69 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500394
# Completed : 70 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500352
# Completed : 71 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500435
# Completed : 72 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500355
# Completed : 73 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500411
# Completed : 74 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500401
# Completed : 75 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500415
# Completed : 76 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500393
# Completed : 77 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500396
# Completed : 78 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500391
# Completed : 79 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500395
# Completed : 80 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500380
# Completed : 81 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500450
# Completed : 82 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500413
# Completed : 83 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500359
# Completed : 84 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500381
# Completed : 85 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500443
# Completed : 86 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500382
# Completed : 87 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500363
# Completed : 88 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500432
# Completed : 89 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500400
# Completed : 90 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500398
# Completed : 91 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500434
# Completed : 92 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500377
# Completed : 93 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500428
# Completed : 94 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500408
# Completed : 95 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500364
# Completed : 96 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500379
# Completed : 97 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500420
# Completed : 98 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500354
# Completed : 99 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500373
# Completed : 100 games.
#
#
#
#
# Finished collecting dataframes for all games.
# 100 games counted

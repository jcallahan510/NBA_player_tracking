# %%
import pandas as pd
import os
import sys
import json
#!pip install movement
#import movement.config as CONFIG

# %%
with open('data/0021500520.json') as file:
    data = json.load(file)
    
file.close()

# %%
movement_headers = ["team_id", "player_id", "x_loc", "y_loc", "radius", "game_clock", "shot_clock", "quarter", "game_id",
                    "event_id"]

csv_path = '/Users/Joey/Projects/xefgi/data/'
game_id = '0021500520'

moments = []

events = data['events']
for event in events:
    event_id = event['eventId']
    movement_data = event['moments']
    for moment in movement_data:
        for player in moment[5]:
            player.extend((moment[2], moment[3], moment[0], game_id, event_id))
            moments.append(player)
# movement frame is complete for game
movement = pd.DataFrame(moments, columns=movement_headers)
movement.to_csv('%s/%s.csv' % (csv_path, game_id), index=False)

# %%
movement = pd.read_csv(csv_path+'0021500504.csv')
events = pd.read_csv(csv_path+'0021500504_e.csv')

# %%
import pandas
import os
import sys
import json

#import movement.config as CONFIG

data_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/'
csv_path = '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped/csv_folder/'
files = os.listdir(data_path)

if not os.path.exists(csv_path):
    os.makedirs(csv_path)

count = 0
movement_headers = ["team_id", "player_id", "x_loc", "y_loc", "radius", "game_clock", "shot_clock", "quarter", "game_id",
                    "event_id"]
for file in files:
    if '.json' not in file:
        continue
    try:
        count = count + 1
        
        if count > 50:
            break
        
        file_data = open('%s/%s' % (data_path, file))
        game_id = file.replace('.json', '')
        data = json.load(file_data)
        events = data['events']
        moments = []

        for event in events:
            event_id = event['eventId']
            movement_data = event['moments']
            for moment in movement_data:
                for player in moment[5]:
                    player.extend((moment[2], moment[3], moment[0], game_id, event_id))
                    moments.append(player)

        # movement frame is complete for game
        movement = pandas.DataFrame(moments, columns=movement_headers)
        movement.to_csv('%s/%s.csv' % (csv_path, game_id), index=False)
        # movement.to_json('./data/json/' + game_id + '.json', orient='records')
        
        

        print('\n')
        print('\n')
        print('Finished collecting dataframe for Game ID: ' + game_id)
        print('Completed : ' + str(count) + ' games.')
    except Exception as e:
        print('Error in loading: ' + str(file) + ' file, Error: ' + str(e))

print('\n')
print('\n')
print('Finished collecting dataframes for all games.')
print(str(count) + ' games counted')
# Out:
# Finished collecting dataframe for Game ID: 0021500019
# Completed : 1 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500083
# Completed : 2 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500076
# Completed : 3 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500048
# Completed : 4 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500058
# Completed : 5 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500017
# Completed : 6 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500113
# Completed : 7 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500102
# Completed : 8 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500074
# Completed : 9 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500035
# Completed : 10 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500025
# Completed : 11 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500101
# Completed : 12 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500009
# Completed : 13 games.
# Error in loading: 0021500119.json.filepart file, Error: [Errno 2] No such file or directory: '/data/p_dsi/nba_player_movement/data_unzipped/data_unzipped//0021500119.json.filepart'
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500099
# Completed : 15 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500097
# Completed : 16 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500064
# Completed : 17 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500111
# Completed : 18 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500092
# Completed : 19 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500059
# Completed : 20 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500073
# Completed : 21 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500001
# Completed : 22 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500011
# Completed : 23 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500042
# Completed : 24 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500114
# Completed : 25 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500065
# Completed : 26 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500005
# Completed : 27 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500061
# Completed : 28 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500096
# Completed : 29 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500109
# Completed : 30 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500043
# Completed : 31 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500093
# Completed : 32 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500024
# Completed : 33 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500105
# Completed : 34 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500118
# Completed : 35 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500041
# Completed : 36 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500003
# Completed : 37 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500103
# Completed : 38 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500068
# Completed : 39 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500107
# Completed : 40 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500018
# Completed : 41 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500066
# Completed : 42 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500020
# Completed : 43 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500047
# Completed : 44 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500015
# Completed : 45 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500027
# Completed : 46 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500007
# Completed : 47 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500069
# Completed : 48 games.
#
#
#
#
# Finished collecting dataframe for Game ID: 0021500067
# Completed : 49 games.
#
#
#
#
# Finished collecting dataframes for all games.
# 50 games counted
